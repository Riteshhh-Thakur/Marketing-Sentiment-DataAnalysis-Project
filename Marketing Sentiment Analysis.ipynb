# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import pyodbc
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download the VADER lexicon for sentiment analysis if not already present.  
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ritesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
analyzer = SentimentIntensityAnalyzer()

text = "This product is absolutely amazing and worth buying!"
score = analyzer.polarity_scores(text)

print(score)
# Out:
# {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.7614}

# %%
analyzer = SentimentIntensityAnalyzer()
score = analyzer.polarity_scores("This was the worst experience of my life. Totally disappointed.")
print(score)
# Out:
# {'neg': 0.484, 'neu': 0.516, 'pos': 0.0, 'compound': -0.8173}

# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
# We will import that file from postgre SQL

# %%
mpp = pd.read_csv(r"C:\Users\ritesh\Desktop\Marketing Project\customer_ka_reviews _taken_from_sql.csv")

# %%
mpp
# Out:
#       review_id  customer_id  product_id review_date  rating  \
# 0             1           77          18  2023-12-23       3
# 1             2           80          19  2024-12-25       5
# 2             3           50          13  2025-01-26       4
# 3             4           78          15  2025-04-21       3
# 4             5           64           2  2023-07-16       3
# ...         ...          ...         ...         ...     ...
# 1358       1359           28           4  2023-05-25       3
# 1359       1360           58          12  2023-11-13       2
# 1360       1361           96          15  2023-03-07       5
# 1361       1362           99           2  2025-12-03       1
# 1362       1363           16           4  2024-07-16       2
#
#                                     replace
# 0      Average experience, nothing special.
# 1                The quality is  top-notch.
# 2        Five stars for the quick delivery.
# 3       Good quality, but could be cheaper.
# 4      Average experience, nothing special.
# ...                                     ...
# 1358                   Not worth the money.
# 1359  Average  experience, nothing special.
# 1360     Customer support was very helpful.
# 1361  Product did not meet my expectations.
# 1362              The product arrived late.
#
# [1363 rows x 6 columns]

# %%
# As we have imported from sql we need to rename the replace column 
mpp = mpp.rename( columns = {'replace' : 'review_text'})

# %%
# Checking the change happened 
mpp.head(1)
# Out:
#    review_id  customer_id  product_id review_date  rating  \
# 0          1           77          18  2023-12-23       3
#
#                             review_text
# 0  Average experience, nothing special.

# %%
# Checking the excat number of the coilumn and rows are there or not 
mpp.shape
# Out:
# (1363, 6)

# %%
mpp.size
# Out:
# 8178

# %%
mpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363 entries, 0 to 1362
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    1363 non-null   int64
#  1   customer_id  1363 non-null   int64
#  2   product_id   1363 non-null   int64
#  3   review_date  1363 non-null   object
#  4   rating       1363 non-null   int64
#  5   review_text  1363 non-null   object
# dtypes: int64(4), object(2)
# memory usage: 64.0+ KB

# %%
mpp['review_date'] = pd.to_datetime(mpp['review_date'])

# %%
mpp.dtypes == 'datetime64[ns]'
# Checking whether it is applied or not
# Out:
# review_id      False
# customer_id    False
# product_id     False
# review_date     True
# rating         False
# review_text    False
# dtype: bool

# %%
mpp.describe(include ='all')
# Out:
#          review_id  customer_id   product_id                    review_date  \
# count   1363.00000  1363.000000  1363.000000                           1363
# unique         NaN          NaN          NaN                            NaN
# top            NaN          NaN          NaN                            NaN
# freq           NaN          NaN          NaN                            NaN
# mean     682.00000    51.701394    10.337491  2024-07-08 06:01:19.236977408
# min        1.00000     1.000000     1.000000            2023-01-01 00:00:00
# 25%      341.50000    27.000000     5.000000            2023-10-09 00:00:00
# 50%      682.00000    53.000000    10.000000            2024-07-08 00:00:00
# 75%     1022.50000    77.000000    15.000000            2025-04-16 00:00:00
# max     1363.00000   100.000000    20.000000            2025-12-31 00:00:00
# std      393.60852    28.605493     5.702922                            NaN
#
#              rating                review_text
# count   1363.000000                       1363
# unique          NaN                        102
# top             NaN  The quality is top-notch.
# freq            NaN                         97
# mean       3.686720                        NaN
# min        1.000000                        NaN
# 25%        3.000000                        NaN
# 50%        4.000000                        NaN
# 75%        5.000000                        NaN
# max        5.000000                        NaN
# std        1.180243                        NaN

# %%
# chgecking for the null values in the table
mpp.isnull().sum()
# Out:
# review_id      0
# customer_id    0
# product_id     0
# review_date    0
# rating         0
# review_text    0
# dtype: int64

# %%
# Checking for duplicated values 
mpp.duplicated().sum()
# Out:
# np.int64(0)

# %%
mpp['review_text'].unique()
# Out:
# array(['Average experience, nothing special.',
#        'The quality is  top-notch.', 'Five stars for the quick delivery.',
#        'Good quality, but could be cheaper.',
#        'Customer support was very helpful.', 'The quality  is top-notch.',
#        'I love this product, will buy again!',
#        'Excellent product, highly recommend!',
#        'Great purchase, very satisfied.',
#        'Product did  not meet my expectations.', 'Not worth the money.',
#        'Shipping was fast and the item was well-packaged.',
#        'The quality is top-notch.',
#        'I had a bad experience with this product.',
#        'Amazing value for the price.',
#        'I love this  product, will buy again!',
#        'Good quality, but could be  cheaper.',
#        'Average experience, nothing  special.',
#        'Five stars  for the quick delivery.',
#        'Exceeded my  expectations!',
#        'Excellent product,  highly recommend!',
#        'Shipping was fast and the item  was well-packaged.',
#        'Good quality, but could  be cheaper.',
#        'The product stopped working after a month.',
#        'Five stars for  the quick delivery.',
#        'Customer support was  very helpful.',
#        'Disappointed with the performance.',
#        'The product  is okay, but the instructions were unclear.',
#        'The build quality is impressive.',
#        'Great purchase,  very satisfied.',
#        'I love this product, will buy  again!',
#        'The product is okay, but the instructions were unclear.',
#        'Shipping was fast  and the item was well-packaged.',
#        'The  build quality is impressive.', 'The product arrived  late.',
#        'Shipping  was fast and the item was well-packaged.',
#        'Not  worth the money.', 'Exceeded my expectations!',
#        'I love  this product, will buy again!',
#        'The product  arrived late.',
#        'Five stars for the  quick delivery.',
#        'Customer  support was very helpful.', 'The product arrived late.',
#        'Great purchase, very  satisfied.',
#        'Great  purchase, very satisfied.',
#        'Product did not meet my expectations.',
#        'Amazing value for  the price.', 'Amazing value for the  price.',
#        'The  product is okay, but the instructions were unclear.',
#        'Good quality, but  could be cheaper.',
#        'I love this product,  will buy again!',
#        'Product did not  meet my expectations.',
#        'Good  quality, but could be cheaper.',
#        'Product did not meet  my expectations.',
#        'Five stars for the quick  delivery.',
#        'The product is okay, but the instructions were  unclear.',
#        'The  quality is top-notch.',
#        'Terrible customer service, would not buy again.',
#        'Shipping was fast and  the item was well-packaged.',
#        'Amazing value  for the price.',
#        'Excellent product, highly  recommend!',
#        'Not  satisfied, the product broke after a week.',
#        'The build quality is  impressive.',
#        'Shipping was fast and the  item was well-packaged.',
#        'The product is  okay, but the instructions were unclear.',
#        'The build quality  is impressive.',
#        'The color was different from what was shown.',
#        'I love this product, will  buy again!', 'Not worth  the money.',
#        'Average  experience, nothing special.',
#        'I  love this product, will buy again!',
#        'Shipping was  fast and the item was well-packaged.',
#        'Disappointed  with the performance.',
#        'The product is okay, but  the instructions were unclear.',
#        'Not worth the  money.',
#        'Not satisfied, the product broke after a week.',
#        'The product  stopped working after a month.',
#        'Good quality,  but could be cheaper.',
#        'Disappointed with the  performance.',
#        'The product is okay, but the  instructions were unclear.',
#        'Not satisfied, the product broke after a  week.',
#        'The build  quality is impressive.',
#        'Customer support  was very helpful.',
#        'Product  did not meet my expectations.',
#        'Average experience,  nothing special.',
#        'Terrible customer service, would not  buy again.',
#        'Five  stars for the quick delivery.',
#        'Exceeded  my expectations!', 'Amazing  value for the price.',
#        'The product is okay, but the instructions  were unclear.',
#        'Excellent  product, highly recommend!',
#        'The  product arrived late.',
#        'The product is okay,  but the instructions were unclear.',
#        'Shipping was fast and the item was  well-packaged.',
#        'Product did not meet my  expectations.',
#        'I had a bad experience  with this product.',
#        'Customer support was very  helpful.',
#        'Terrible customer service, would  not buy again.',
#        'Disappointed with  the performance.',
#        'Not satisfied, the  product broke after a week.',
#        'Not satisfied, the product broke  after a week.',
#        'Terrible  customer service, would not buy again.'], dtype=object)

# %%
# Initialize the VADER sentiment intensity analyzer for analyzing the sentiment of text data
siya = SentimentIntensityAnalyzer()

# %%
# Making a user defined  function to calculate sentiment scores using VADER
def calculate_sentiment(review):
    # Get the sentiment scores for the review text
    sentiment = siya.polarity_scores(review)
    # Return the compound score, which is a normalized score between -1 (most negative) and 1 (most positive)
    return sentiment['compound']

# %%
# Define a function to categorize sentiment using both the sentiment score and the review rating
def categorize_sentiment(score, rating):
    # Use both the text sentiment score and the numerical rating to determine sentiment category
    if score > 0.05:  # Positive sentiment score
        if rating >= 4:
            return 'Positive'  # High rating and positive sentiment
        elif rating == 3:
            return 'Mixed Positive'  # Neutral rating but positive sentiment
        else:
            return 'Mixed Negative'  # Low rating but positive sentiment
    elif score < -0.05:  # Negative sentiment score
        if rating <= 2:
            return 'Negative'  # Low rating and negative sentiment
        elif rating == 3:
            return 'Mixed Negative'  # Neutral rating but negative sentiment
        else:
            return 'Mixed Positive'  # High rating but negative sentiment
    else:  # Neutral sentiment score
        if rating >= 4:
            return 'Positive'  # High rating with neutral sentiment
        elif rating <= 2:
            return 'Negative'  # Low rating with neutral sentiment
        else:
            return 'Neutral'  # Neutral rating and neutral sentiment

# %%
# Define a function to bucket sentiment scores into text ranges
def sentiment_bucket(score):
    if score >= 0.5:
        return '0.5 to 1.0'  # Strongly positive sentiment 
    elif 0.0 <= score < 0.5:
        return '0.0 to 0.49'  # Mildly positive sentiment
    elif -0.5 <= score < 0.0:
        return '-0.49 to 0.0'  # Mildly negative sentiment
    else:
        return '-1.0 to -0.5'  # Strongly negative sentiment

# %%
# Apply sentiment analysis to calculate sentiment scores for each review
mpp['SentimentScore'] = mpp['review_text'].apply(calculate_sentiment)

# %%
mpp.head()
# Out:
#    review_id  customer_id  product_id review_date  rating  \
# 0          1           77          18  2023-12-23       3
# 1          2           80          19  2024-12-25       5
# 2          3           50          13  2025-01-26       4
# 3          4           78          15  2025-04-21       3
# 4          5           64           2  2023-07-16       3
#
#                             review_text  SentimentScore
# 0  Average experience, nothing special.         -0.3089
# 1            The quality is  top-notch.          0.0000
# 2    Five stars for the quick delivery.          0.0000
# 3   Good quality, but could be cheaper.          0.2382
# 4  Average experience, nothing special.         -0.3089

# %%
# Apply sentiment categorization using both text and rating
mpp['SentimentCategory'] = mpp.apply(
    lambda row: categorize_sentiment(row['SentimentScore'], row['rating']), axis=1)

# %%
mpp.tail(2)
# Out:
#       review_id  customer_id  product_id review_date  rating  \
# 1361       1362           99           2  2025-12-03       1
# 1362       1363           16           4  2024-07-16       2
#
#                                 review_text  SentimentScore SentimentCategory
# 1361  Product did not meet my expectations.             0.0          Negative
# 1362              The product arrived late.             0.0          Negative

# %%
# Apply sentiment bucketing to categorize scores into defined ranges
mpp['SentimentBucket'] = mpp['SentimentScore'].apply(sentiment_bucket)

# %%
mpp
# Out:
#       review_id  customer_id  product_id review_date  rating  \
# 0             1           77          18  2023-12-23       3
# 1             2           80          19  2024-12-25       5
# 2             3           50          13  2025-01-26       4
# 3             4           78          15  2025-04-21       3
# 4             5           64           2  2023-07-16       3
# ...         ...          ...         ...         ...     ...
# 1358       1359           28           4  2023-05-25       3
# 1359       1360           58          12  2023-11-13       2
# 1360       1361           96          15  2023-03-07       5
# 1361       1362           99           2  2025-12-03       1
# 1362       1363           16           4  2024-07-16       2
#
#                                 review_text  SentimentScore SentimentCategory  \
# 0      Average experience, nothing special.         -0.3089    Mixed Negative
# 1                The quality is  top-notch.          0.0000          Positive
# 2        Five stars for the quick delivery.          0.0000          Positive
# 3       Good quality, but could be cheaper.          0.2382    Mixed Positive
# 4      Average experience, nothing special.         -0.3089    Mixed Negative
# ...                                     ...             ...               ...
# 1358                   Not worth the money.         -0.1695    Mixed Negative
# 1359  Average  experience, nothing special.         -0.3089          Negative
# 1360     Customer support was very helpful.          0.6997          Positive
# 1361  Product did not meet my expectations.          0.0000          Negative
# 1362              The product arrived late.          0.0000          Negative
#
#      SentimentBucket
# 0       -0.49 to 0.0
# 1        0.0 to 0.49
# 2        0.0 to 0.49
# 3        0.0 to 0.49
# 4       -0.49 to 0.0
# ...              ...
# 1358    -0.49 to 0.0
# 1359    -0.49 to 0.0
# 1360      0.5 to 1.0
# 1361     0.0 to 0.49
# 1362     0.0 to 0.49
#
# [1363 rows x 9 columns]

# %%
mpp.tail(40)
# Out:
#       review_id  customer_id  product_id review_date  rating  \
# 1323       1324           36          10  2025-12-27       4
# 1324       1325           66          12  2024-08-07       3
# 1325       1326           69           4  2024-06-09       5
# 1326       1327           37           9  2025-05-20       2
# 1327       1328           97          11  2025-12-23       4
# 1328       1329           45          19  2024-01-03       2
# 1329       1330           24          12  2025-05-31       2
# 1330       1331           88           5  2025-06-02       4
# 1331       1332           72           4  2024-06-15       5
# 1332       1333            6           3  2023-12-06       3
# 1333       1334           39          11  2025-04-03       4
# 1334       1335           43          15  2025-03-06       4
# 1335       1336           95           9  2023-11-27       1
# 1336       1337           89           4  2023-10-09       3
# 1337       1338           44          13  2025-02-01       2
# 1338       1339           76          19  2024-11-01       5
# 1339       1340           62           7  2025-07-10       3
# 1340       1341           64           7  2023-06-21       2
# 1341       1342           91           1  2025-06-03       5
# 1342       1343           39           4  2025-04-10       5
# 1343       1344           31          20  2025-05-16       5
# 1344       1345           55          18  2023-10-14       5
# 1345       1346           47           6  2024-10-14       2
# 1346       1347           21          11  2025-07-16       4
# 1347       1348           45          19  2024-02-14       5
# 1348       1349           22          10  2025-04-11       4
# 1349       1350           69           9  2024-02-01       3
# 1350       1351           30          20  2023-07-23       1
# 1351       1352           50          14  2025-06-25       5
# 1352       1353           34           5  2024-06-30       5
# 1353       1354           53           8  2024-05-08       5
# 1354       1355            9          20  2025-05-29       5
# 1355       1356           14          15  2025-04-18       4
# 1356       1357           23          17  2024-01-03       1
# 1357       1358           90          10  2024-01-16       3
# 1358       1359           28           4  2023-05-25       3
# 1359       1360           58          12  2023-11-13       2
# 1360       1361           96          15  2023-03-07       5
# 1361       1362           99           2  2025-12-03       1
# 1362       1363           16           4  2024-07-16       2
#
#                                             review_text  SentimentScore  \
# 1323                 Customer support was very helpful.          0.6997
# 1324               I love this product, will buy again!          0.6696
# 1325                    Great purchase, very satisfied.          0.8016
# 1326               Average experience, nothing special.         -0.3089
# 1327                 Customer support was very helpful.          0.6997
# 1328                               Not worth the money.         -0.1695
# 1329                               Not worth the money.         -0.1695
# 1330                          The quality is top-notch.          0.0000
# 1331                      Amazing value for the  price.          0.7351
# 1332  The product is okay, but the instructions were...         -0.2617
# 1333               I love this product, will buy again!          0.6696
# 1334                          The quality is top-notch.          0.0000
# 1335    Not satisfied, the  product broke after a week.         -0.6288
# 1336               Average experience, nothing special.         -0.3089
# 1337                 Disappointed with the performance.         -0.4767
# 1338                          The quality is top-notch.          0.0000
# 1339                              Not worth  the money.         -0.1695
# 1340              Average experience, nothing  special.         -0.3089
# 1341                 Customer support was very helpful.          0.6997
# 1342                   The build quality is impressive.          0.5106
# 1343                          The quality is top-notch.          0.0000
# 1344               Excellent product, highly recommend!          0.7773
# 1345                          The product arrived late.          0.0000
# 1346  Shipping was fast and the item was well-packaged.          0.0000
# 1347               I love this product, will buy again!          0.6696
# 1348                 Five stars for the quick delivery.          0.0000
# 1349  The product is okay, but the instructions were...         -0.2617
# 1350    Not satisfied, the product broke  after a week.         -0.6288
# 1351                         The quality is  top-notch.          0.0000
# 1352                          The quality is top-notch.          0.0000
# 1353              Excellent  product, highly recommend!          0.7773
# 1354                 Customer support was very helpful.          0.6997
# 1355                          The quality is top-notch.          0.0000
# 1356   Terrible  customer service, would not buy again.         -0.4767
# 1357                              Not worth  the money.         -0.1695
# 1358                               Not worth the money.         -0.1695
# 1359              Average  experience, nothing special.         -0.3089
# 1360                 Customer support was very helpful.          0.6997
# 1361              Product did not meet my expectations.          0.0000
# 1362                          The product arrived late.          0.0000
#
#      SentimentCategory SentimentBucket
# 1323          Positive      0.5 to 1.0
# 1324    Mixed Positive      0.5 to 1.0
# 1325          Positive      0.5 to 1.0
# 1326          Negative    -0.49 to 0.0
# 1327          Positive      0.5 to 1.0
# 1328          Negative    -0.49 to 0.0
# 1329          Negative    -0.49 to 0.0
# 1330          Positive     0.0 to 0.49
# 1331          Positive      0.5 to 1.0
# 1332    Mixed Negative    -0.49 to 0.0
# 1333          Positive      0.5 to 1.0
# 1334          Positive     0.0 to 0.49
# 1335          Negative    -1.0 to -0.5
# 1336    Mixed Negative    -0.49 to 0.0
# 1337          Negative    -0.49 to 0.0
# 1338          Positive     0.0 to 0.49
# 1339    Mixed Negative    -0.49 to 0.0
# 1340          Negative    -0.49 to 0.0
# 1341          Positive      0.5 to 1.0
# 1342          Positive      0.5 to 1.0
# 1343          Positive     0.0 to 0.49
# 1344          Positive      0.5 to 1.0
# 1345          Negative     0.0 to 0.49
# 1346          Positive     0.0 to 0.49
# 1347          Positive      0.5 to 1.0
# 1348          Positive     0.0 to 0.49
# 1349    Mixed Negative    -0.49 to 0.0
# 1350          Negative    -1.0 to -0.5
# 1351          Positive     0.0 to 0.49
# 1352          Positive     0.0 to 0.49
# 1353          Positive      0.5 to 1.0
# 1354          Positive      0.5 to 1.0
# 1355          Positive     0.0 to 0.49
# 1356          Negative    -0.49 to 0.0
# 1357    Mixed Negative    -0.49 to 0.0
# 1358    Mixed Negative    -0.49 to 0.0
# 1359          Negative    -0.49 to 0.0
# 1360          Positive      0.5 to 1.0
# 1361          Negative     0.0 to 0.49
# 1362          Negative     0.0 to 0.49

# %%
mpp.to_csv('cleaned_data.csv', index=False)
